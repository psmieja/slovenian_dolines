# %%
import numpy as np
import matplotlib.pyplot as plt

from lidar_data_analyzer import LidarDataSet

# %%
lds = LidarDataSet.from_npy_file("./data_sim/test_07_t_25.npy", maxR=20)

# %%
lds.dataset
# Out:
# array([[128, 128, 128, ..., 127, 127, 127],
#        [128, 128, 128, ..., 127, 128, 128],
#        [128, 128, 128, ..., 128, 128, 128],
#        ...,
#        [127, 127, 128, ..., 126, 126, 127],
#        [127, 127, 128, ..., 126, 127, 127],
#        [127, 128, 128, ..., 127, 127, 127]])

# %%
lds.plot(edges=False,
         centers=False,
         analyzed_region=False,
         hillshade=True,
         verbose=False,
         fig_size=None,
         save=False,
         filename="output.png")
# Out:
# PLOTTING

# %%
lds.find_sinkholes(min_dist=10)
# Out:
# LOG: find_sinkholes: found 10 sinkholes

# %%
lds.plot(edges=False,
         centers=True,
         analyzed_region=False,
         hillshade=True,
         verbose=False,
         fig_size=None,
         save=False,
         filename="output.png")
# Out:
# PLOTTING

# %%
lds.plot(edges=False,
         centers=True,
         analyzed_region=False,
         hillshade=False,
         verbose=False,
         fig_size=None,
         save=False,
         filename="output.png")
# Out:
# PLOTTING

# %%
lds.find_sinkhole_edges()
# Out:
# finding edge #:0
# finding edge #:3
# finding edge #:6
# finding edge #:7
# /home/pt/PROJECTS/LEJE/analysis/lidar_data_analyzer/LidarDataSet.py:379: ShapelyDeprecationWarning: Iteration over multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   corr_edge_poly = corr_edge_poly[np.argmax([seg.area for seg in corr_edge_poly])]
# /home/pt/PROJECTS/LEJE/analysis/lidar_data_analyzer/LidarDataSet.py:379: ShapelyDeprecationWarning: __getitem__ for multi-part geometries is deprecated and will be removed in Shapely 2.0. Use the `geoms` property to access the constituent parts of a multi-part geometry.
#   corr_edge_poly = corr_edge_poly[np.argmax([seg.area for seg in corr_edge_poly])]

# %%
lds.plot(edges=True,
         centers=True,
         analyzed_region=False,
         hillshade=False,
         verbose=False,
         fig_size=None,
         save=False,
         filename="output.png")
# Out:
# PLOTTING

# %%
plt.imshow(np.transpose(lds.dataset), origin="lower")

# %%
plt.imshow(np.transpose(lds.dataset), origin="lower")

# %%
plt.imshow(np.transpose(lds.dataset_filtered), origin="lower")

# %%
from skimage.feature import peak_local_max

# %%
plt.imshow(np.transpose(lds.dataset), origin="lower")
plt.scatter(lds.sinkholes[:,0], doline_centers[:,1])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [7], in <cell line: 2>()
#       1 plt.imshow(np.transpose(lds.dataset), origin="lower")
# ----> 2 plt.scatter(doline_centers[:,0], doline_centers[:,1])
#       3 plt.show()
#
# NameError: name 'doline_centers' is not defined
